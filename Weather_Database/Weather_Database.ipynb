# %%
# Import dependencies and API key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the rquests library
import requests

# Import the API key
from config import w_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create 2000 random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

coordinates = list(zip(lats, lngs))

# %%
# Get the nearest city using the citipy module
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

print(len(cities))
# Out:
# 785

# %%
# Perform an API call with the OpenWeatherMap
base_url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + w_key

# Create an empty list to hold the weather data
city_data = []

# Print the beginnning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL for each city
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Current Description": city_desc})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the Data Loading is complete
print("---------------------------")
print("Data Retrieval Complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | okaihau
# Processing Record 2 of Set 1 | praia da vitoria
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | asau
# Processing Record 5 of Set 1 | eldorado
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | the valley
# Processing Record 8 of Set 1 | alzamay
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | lavumisa
# Processing Record 13 of Set 1 | kieta
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | pacific grove
# Processing Record 17 of Set 1 | kattivakkam
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | deniliquin
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | hamilton
# Processing Record 24 of Set 1 | saldanha
# Processing Record 25 of Set 1 | teguldet
# Processing Record 26 of Set 1 | pangody
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | pirovskoye
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | pyu
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | fruitvale
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | la palma
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | karratha
# Processing Record 41 of Set 1 | auki
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | harwich
# Processing Record 44 of Set 1 | hualmay
# Processing Record 45 of Set 1 | emerald
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | palu
# Processing Record 48 of Set 1 | launceston
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | abancay
# Processing Record 2 of Set 2 | bilma
# Processing Record 3 of Set 2 | sao jose da coroa grande
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | belaya gora
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | riyadh
# Processing Record 10 of Set 2 | amos
# Processing Record 11 of Set 2 | nhulunbuy
# Processing Record 12 of Set 2 | kinel
# Processing Record 13 of Set 2 | whitehorse
# Processing Record 14 of Set 2 | todos santos
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | vuktyl
# Processing Record 17 of Set 2 | sangar
# Processing Record 18 of Set 2 | half moon bay
# Processing Record 19 of Set 2 | wangkui
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | bousso
# Processing Record 27 of Set 2 | san francisco
# Processing Record 28 of Set 2 | jaitaran
# Processing Record 29 of Set 2 | gillette
# Processing Record 30 of Set 2 | pangnirtung
# Processing Record 31 of Set 2 | mezen
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | gemena
# Processing Record 34 of Set 2 | klaksvik
# Processing Record 35 of Set 2 | santa catalina
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | san isidro
# Processing Record 38 of Set 2 | gwadar
# Processing Record 39 of Set 2 | minnedosa
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | waingapu
# Processing Record 42 of Set 2 | bubaque
# Processing Record 43 of Set 2 | padang
# Processing Record 44 of Set 2 | fort nelson
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | san ramon de la nueva oran
# Processing Record 47 of Set 2 | seoul
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | bonthe
# Processing Record 50 of Set 2 | najran
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | caxito
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 3 | camacha
# Processing Record 9 of Set 3 | khowst
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | kibala
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | jiblah
# Processing Record 14 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | ngunguru
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | ankang
# Processing Record 19 of Set 3 | salalah
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | kapoeta
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | laguna
# Processing Record 24 of Set 3 | procida
# Processing Record 25 of Set 3 | lae
# Processing Record 26 of Set 3 | dzerzhinsk
# Processing Record 27 of Set 3 | stokmarknes
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | hudson bay
# Processing Record 30 of Set 3 | arrecife
# Processing Record 31 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | saint anthony
# Processing Record 35 of Set 3 | poum
# Processing Record 36 of Set 3 | hoa binh
# Processing Record 37 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 38 of Set 3 | avdon
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | kapaa
# Processing Record 42 of Set 3 | tete
# Processing Record 43 of Set 3 | rock sound
# Processing Record 44 of Set 3 | alnavar
# Processing Record 45 of Set 3 | dryden
# Processing Record 46 of Set 3 | moron
# Processing Record 47 of Set 3 | flin flon
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | lishu
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | lebu
# Processing Record 2 of Set 4 | bintulu
# Processing Record 3 of Set 4 | bluff
# Processing Record 4 of Set 4 | dondaicha
# Processing Record 5 of Set 4 | kitui
# Processing Record 6 of Set 4 | narva
# Processing Record 7 of Set 4 | honningsvag
# Processing Record 8 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | patiya
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | saurimo
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | christchurch
# Processing Record 16 of Set 4 | lavrentiya
# Processing Record 17 of Set 4 | tura
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | katangli
# Processing Record 20 of Set 4 | grand gaube
# Processing Record 21 of Set 4 | omboue
# Processing Record 22 of Set 4 | magadan
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | vysokogornyy
# Processing Record 25 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | kloulklubed
# Processing Record 28 of Set 4 | gat
# Processing Record 29 of Set 4 | antalya
# Processing Record 30 of Set 4 | vaini
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | batagay-alyta
# Processing Record 33 of Set 4 | san rafael
# Processing Record 34 of Set 4 | cascais
# Processing Record 35 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | panormos
# Processing Record 38 of Set 4 | melo
# Processing Record 39 of Set 4 | gamba
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | amberley
# Processing Record 42 of Set 4 | kargasok
# Processing Record 43 of Set 4 | jieshi
# Processing Record 44 of Set 4 | myitkyina
# Processing Record 45 of Set 4 | lanzhou
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | qui nhon
# Processing Record 48 of Set 4 | paltinis
# Processing Record 49 of Set 4 | sutysky
# Processing Record 50 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 5 | puli
# Processing Record 2 of Set 5 | hargeysa
# Processing Record 3 of Set 5 | troitsko-pechorsk
# Processing Record 4 of Set 5 | taoudenni
# Processing Record 5 of Set 5 | shah alam
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | taltal
# Processing Record 8 of Set 5 | yetholm
# City not found. Skipping...
# Processing Record 9 of Set 5 | port moresby
# Processing Record 10 of Set 5 | sakaiminato
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | fortuna
# Processing Record 14 of Set 5 | salinas
# Processing Record 15 of Set 5 | seabra
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | palmer
# Processing Record 18 of Set 5 | berezovyy
# Processing Record 19 of Set 5 | neka
# Processing Record 20 of Set 5 | tual
# Processing Record 21 of Set 5 | maine-soroa
# Processing Record 22 of Set 5 | monduli
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | sinnamary
# Processing Record 25 of Set 5 | bozoum
# Processing Record 26 of Set 5 | hofn
# Processing Record 27 of Set 5 | guangyuan
# Processing Record 28 of Set 5 | uthal
# Processing Record 29 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | bredasdorp
# Processing Record 32 of Set 5 | brae
# Processing Record 33 of Set 5 | namibe
# Processing Record 34 of Set 5 | egvekinot
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | elizabeth city
# Processing Record 37 of Set 5 | santa rosa
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | catamarca
# Processing Record 40 of Set 5 | sinop
# Processing Record 41 of Set 5 | henties bay
# Processing Record 42 of Set 5 | khatanga
# Processing Record 43 of Set 5 | shimoda
# Processing Record 44 of Set 5 | tomatlan
# Processing Record 45 of Set 5 | zhanakorgan
# Processing Record 46 of Set 5 | tasiilaq
# Processing Record 47 of Set 5 | cap-aux-meules
# Processing Record 48 of Set 5 | mantua
# Processing Record 49 of Set 5 | kampene
# Processing Record 50 of Set 5 | lagunas
# Processing Record 1 of Set 6 | quang ngai
# Processing Record 2 of Set 6 | gazojak
# Processing Record 3 of Set 6 | port alfred
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | okhotsk
# Processing Record 6 of Set 6 | aklavik
# Processing Record 7 of Set 6 | sturgeon falls
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | yenagoa
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 12 of Set 6 | alta floresta
# Processing Record 13 of Set 6 | dhola
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | necochea
# Processing Record 16 of Set 6 | otradnoye
# Processing Record 17 of Set 6 | margate
# Processing Record 18 of Set 6 | kodinsk
# Processing Record 19 of Set 6 | tuatapere
# Processing Record 20 of Set 6 | turka
# Processing Record 21 of Set 6 | san andres
# Processing Record 22 of Set 6 | santo domingo
# Processing Record 23 of Set 6 | dikson
# Processing Record 24 of Set 6 | vitim
# Processing Record 25 of Set 6 | enid
# Processing Record 26 of Set 6 | bagua grande
# Processing Record 27 of Set 6 | saskylakh
# Processing Record 28 of Set 6 | broome
# Processing Record 29 of Set 6 | ibra
# Processing Record 30 of Set 6 | camalu
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | varhaug
# Processing Record 33 of Set 6 | gimli
# Processing Record 34 of Set 6 | puerto ayora
# Processing Record 35 of Set 6 | codrington
# Processing Record 36 of Set 6 | maceio
# Processing Record 37 of Set 6 | port blair
# Processing Record 38 of Set 6 | san jeronimo
# Processing Record 39 of Set 6 | ennis
# Processing Record 40 of Set 6 | lethem
# Processing Record 41 of Set 6 | kodinar
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | puerto cabello
# Processing Record 45 of Set 6 | kirakira
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | atakpame
# Processing Record 48 of Set 6 | jinchang
# Processing Record 49 of Set 6 | iberia
# Processing Record 50 of Set 6 | itarema
# Processing Record 1 of Set 7 | vieux-habitants
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | rocha
# Processing Record 4 of Set 7 | westport
# Processing Record 5 of Set 7 | shieli
# Processing Record 6 of Set 7 | samarai
# Processing Record 7 of Set 7 | djambala
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | lexington
# Processing Record 10 of Set 7 | gaoual
# Processing Record 11 of Set 7 | ayan
# Processing Record 12 of Set 7 | machali
# Processing Record 13 of Set 7 | rochegda
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | kahului
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | lincoln
# Processing Record 18 of Set 7 | maracas
# Processing Record 19 of Set 7 | ravar
# Processing Record 20 of Set 7 | talara
# Processing Record 21 of Set 7 | toba
# Processing Record 22 of Set 7 | acarau
# Processing Record 23 of Set 7 | nogliki
# Processing Record 24 of Set 7 | sembakung
# Processing Record 25 of Set 7 | santa maria
# Processing Record 26 of Set 7 | amudat
# Processing Record 27 of Set 7 | warmbad
# Processing Record 28 of Set 7 | iqaluit
# Processing Record 29 of Set 7 | yeniseysk
# Processing Record 30 of Set 7 | adrar
# Processing Record 31 of Set 7 | saint-francois
# Processing Record 32 of Set 7 | ixtapa
# Processing Record 33 of Set 7 | tezu
# Processing Record 34 of Set 7 | jaisalmer
# Processing Record 35 of Set 7 | antibes
# Processing Record 36 of Set 7 | glenwood springs
# Processing Record 37 of Set 7 | catuday
# Processing Record 38 of Set 7 | kudahuvadhoo
# Processing Record 39 of Set 7 | sola
# Processing Record 40 of Set 7 | san luis
# Processing Record 41 of Set 7 | taylor
# Processing Record 42 of Set 7 | chapais
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | kurilsk
# Processing Record 45 of Set 7 | carballo
# Processing Record 46 of Set 7 | bulaevo
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | beloha
# Processing Record 50 of Set 7 | giddalur
# Processing Record 1 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | huarmey
# Processing Record 3 of Set 8 | bud
# Processing Record 4 of Set 8 | kavieng
# Processing Record 5 of Set 8 | coihaique
# Processing Record 6 of Set 8 | douglas
# Processing Record 7 of Set 8 | matagami
# Processing Record 8 of Set 8 | rabapatona
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | tateyama
# Processing Record 11 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 8 | winona
# Processing Record 13 of Set 8 | romitan
# Processing Record 14 of Set 8 | tadine
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | ygatimi
# Processing Record 18 of Set 8 | nioro
# Processing Record 19 of Set 8 | abu dhabi
# Processing Record 20 of Set 8 | berlevag
# Processing Record 21 of Set 8 | charters towers
# Processing Record 22 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 8 | port lincoln
# Processing Record 24 of Set 8 | acapulco
# Processing Record 25 of Set 8 | saint george
# Processing Record 26 of Set 8 | jining
# Processing Record 27 of Set 8 | torbay
# Processing Record 28 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 8 | piacabucu
# Processing Record 30 of Set 8 | nichinan
# Processing Record 31 of Set 8 | sitka
# Processing Record 32 of Set 8 | cabo san lucas
# Processing Record 33 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 8 | kijang
# Processing Record 35 of Set 8 | vila velha
# Processing Record 36 of Set 8 | paraiso
# Processing Record 37 of Set 8 | kimbe
# Processing Record 38 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 8 | chililabombwe
# Processing Record 40 of Set 8 | bara
# Processing Record 41 of Set 8 | prince rupert
# Processing Record 42 of Set 8 | pychas
# Processing Record 43 of Set 8 | clevelandia
# Processing Record 44 of Set 8 | lagoa
# Processing Record 45 of Set 8 | george
# Processing Record 46 of Set 8 | steinbach
# Processing Record 47 of Set 8 | vinces
# Processing Record 48 of Set 8 | san patricio
# Processing Record 49 of Set 8 | nantucket
# Processing Record 50 of Set 8 | nabire
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | baiyin
# Processing Record 3 of Set 9 | marevo
# Processing Record 4 of Set 9 | iracoubo
# Processing Record 5 of Set 9 | muravlenko
# Processing Record 6 of Set 9 | whitianga
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | nalut
# Processing Record 9 of Set 9 | pilar
# Processing Record 10 of Set 9 | roebourne
# Processing Record 11 of Set 9 | naze
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | masallatah
# Processing Record 14 of Set 9 | sergeyevka
# Processing Record 15 of Set 9 | dingle
# Processing Record 16 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 9 | camajuani
# Processing Record 18 of Set 9 | bani walid
# Processing Record 19 of Set 9 | stanceni
# Processing Record 20 of Set 9 | bien hoa
# Processing Record 21 of Set 9 | svebolle
# Processing Record 22 of Set 9 | barra do bugres
# Processing Record 23 of Set 9 | rantepao
# Processing Record 24 of Set 9 | lazaro cardenas
# Processing Record 25 of Set 9 | colares
# Processing Record 26 of Set 9 | mindelo
# Processing Record 27 of Set 9 | vylgort
# City not found. Skipping...
# Processing Record 28 of Set 9 | payakumbuh
# Processing Record 29 of Set 9 | pingliang
# Processing Record 30 of Set 9 | ambilobe
# Processing Record 31 of Set 9 | ati
# Processing Record 32 of Set 9 | bojonegoro
# Processing Record 33 of Set 9 | shenzhen
# Processing Record 34 of Set 9 | denpasar
# Processing Record 35 of Set 9 | tyrma
# Processing Record 36 of Set 9 | sulangan
# Processing Record 37 of Set 9 | tirano
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | qaqortoq
# Processing Record 40 of Set 9 | mariental
# Processing Record 41 of Set 9 | portland
# Processing Record 42 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 9 | blagoyevo
# Processing Record 44 of Set 9 | panjakent
# Processing Record 45 of Set 9 | kisangani
# Processing Record 46 of Set 9 | waitara
# Processing Record 47 of Set 9 | peno
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | itoman
# Processing Record 50 of Set 9 | kangaatsiaq
# Processing Record 1 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | olafsvik
# Processing Record 3 of Set 10 | fort-shevchenko
# Processing Record 4 of Set 10 | solnechnyy
# Processing Record 5 of Set 10 | los andes
# Processing Record 6 of Set 10 | malanje
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 10 | kalianget
# Processing Record 11 of Set 10 | sibolga
# Processing Record 12 of Set 10 | saint-paul
# Processing Record 13 of Set 10 | hun
# Processing Record 14 of Set 10 | tabuk
# Processing Record 15 of Set 10 | tautira
# Processing Record 16 of Set 10 | teguise
# Processing Record 17 of Set 10 | atasu
# Processing Record 18 of Set 10 | ambovombe
# Processing Record 19 of Set 10 | moratuwa
# Processing Record 20 of Set 10 | la roche-sur-yon
# Processing Record 21 of Set 10 | honiara
# Processing Record 22 of Set 10 | losinyy
# Processing Record 23 of Set 10 | agropoli
# Processing Record 24 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 10 | kerema
# Processing Record 26 of Set 10 | russell
# Processing Record 27 of Set 10 | isla mujeres
# Processing Record 28 of Set 10 | luanda
# Processing Record 29 of Set 10 | jonkoping
# Processing Record 30 of Set 10 | santa cruz del sur
# Processing Record 31 of Set 10 | aykhal
# Processing Record 32 of Set 10 | dzheguta
# Processing Record 33 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | mayumba
# Processing Record 36 of Set 10 | lorengau
# Processing Record 37 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 38 of Set 10 | porto santo
# Processing Record 39 of Set 10 | swellendam
# Processing Record 40 of Set 10 | kollegal
# Processing Record 41 of Set 10 | aloleng
# Processing Record 42 of Set 10 | naukot
# Processing Record 43 of Set 10 | nizhniy tsasuchey
# Processing Record 44 of Set 10 | beidao
# Processing Record 45 of Set 10 | chimbote
# Processing Record 46 of Set 10 | inuvik
# Processing Record 47 of Set 10 | jibuti
# Processing Record 48 of Set 10 | esperance
# Processing Record 49 of Set 10 | korla
# Processing Record 50 of Set 10 | puerto leguizamo
# Processing Record 1 of Set 11 | shitanjing
# Processing Record 2 of Set 11 | daru
# Processing Record 3 of Set 11 | along
# Processing Record 4 of Set 11 | banda aceh
# Processing Record 5 of Set 11 | provideniya
# Processing Record 6 of Set 11 | narsaq
# Processing Record 7 of Set 11 | ekibastuz
# Processing Record 8 of Set 11 | kruisfontein
# Processing Record 9 of Set 11 | kaeo
# Processing Record 10 of Set 11 | west bay
# Processing Record 11 of Set 11 | jacareacanga
# Processing Record 12 of Set 11 | boralday
# Processing Record 13 of Set 11 | marks
# Processing Record 14 of Set 11 | kuytun
# Processing Record 15 of Set 11 | rupert
# Processing Record 16 of Set 11 | mae sot
# Processing Record 17 of Set 11 | torrington
# Processing Record 18 of Set 11 | khasan
# Processing Record 19 of Set 11 | sambava
# Processing Record 20 of Set 11 | gazanjyk
# Processing Record 21 of Set 11 | santa cruz cabralia
# Processing Record 22 of Set 11 | nome
# Processing Record 23 of Set 11 | shaunavon
# Processing Record 24 of Set 11 | nadym
# Processing Record 25 of Set 11 | ust-maya
# Processing Record 26 of Set 11 | los llanos de aridane
# Processing Record 27 of Set 11 | kalangala
# Processing Record 28 of Set 11 | kemijarvi
# Processing Record 29 of Set 11 | kidal
# Processing Record 30 of Set 11 | bushenyi
# Processing Record 31 of Set 11 | luena
# Processing Record 32 of Set 11 | scarborough
# Processing Record 33 of Set 11 | acurenam
# Processing Record 34 of Set 11 | north marysville
# City not found. Skipping...
# Processing Record 35 of Set 11 | kysyl-syr
# Processing Record 36 of Set 11 | namatanai
# Processing Record 37 of Set 11 | bosaso
# Processing Record 38 of Set 11 | labrea
# Processing Record 39 of Set 11 | lima
# Processing Record 40 of Set 11 | sovetskiy
# Processing Record 41 of Set 11 | cap malheureux
# Processing Record 42 of Set 11 | san jose
# Processing Record 43 of Set 11 | sidney
# Processing Record 44 of Set 11 | lucapa
# Processing Record 45 of Set 11 | filadelfia
# Processing Record 46 of Set 11 | raudeberg
# Processing Record 47 of Set 11 | parabel
# Processing Record 48 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 11 | vostok
# Processing Record 50 of Set 11 | yamada
# Processing Record 1 of Set 12 | gondar
# Processing Record 2 of Set 12 | alyangula
# Processing Record 3 of Set 12 | harper
# Processing Record 4 of Set 12 | delvada
# Processing Record 5 of Set 12 | turukhansk
# Processing Record 6 of Set 12 | boa vista
# Processing Record 7 of Set 12 | nortelandia
# Processing Record 8 of Set 12 | kutum
# Processing Record 9 of Set 12 | santa marta
# Processing Record 10 of Set 12 | ler
# Processing Record 11 of Set 12 | poso
# Processing Record 12 of Set 12 | oktyabrskoye
# Processing Record 13 of Set 12 | saint-georges
# Processing Record 14 of Set 12 | aranos
# Processing Record 15 of Set 12 | hanmer springs
# Processing Record 16 of Set 12 | labytnangi
# Processing Record 17 of Set 12 | kuusamo
# Processing Record 18 of Set 12 | ganzhou
# Processing Record 19 of Set 12 | norfolk
# Processing Record 20 of Set 12 | innisfail
# Processing Record 21 of Set 12 | jinxiang
# Processing Record 22 of Set 12 | kaoma
# Processing Record 23 of Set 12 | auchi
# Processing Record 24 of Set 12 | mahina
# Processing Record 25 of Set 12 | manuk mangkaw
# Processing Record 26 of Set 12 | longyearbyen
# Processing Record 27 of Set 12 | bongor
# Processing Record 28 of Set 12 | dire
# Processing Record 29 of Set 12 | diu
# Processing Record 30 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 12 | gadsden
# Processing Record 32 of Set 12 | kajaani
# Processing Record 33 of Set 12 | olenegorsk
# Processing Record 34 of Set 12 | nanortalik
# Processing Record 35 of Set 12 | shelburne
# Processing Record 36 of Set 12 | talaja
# Processing Record 37 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | bourail
# Processing Record 40 of Set 12 | lucea
# Processing Record 41 of Set 12 | matay
# Processing Record 42 of Set 12 | bilky
# Processing Record 43 of Set 12 | mathathane
# Processing Record 44 of Set 12 | amazar
# Processing Record 45 of Set 12 | bingol
# Processing Record 46 of Set 12 | inverell
# Processing Record 47 of Set 12 | san cristobal
# Processing Record 48 of Set 12 | homer
# Processing Record 49 of Set 12 | tinskoy
# Processing Record 50 of Set 12 | kyren
# Processing Record 1 of Set 13 | alice springs
# Processing Record 2 of Set 13 | dabakala
# Processing Record 3 of Set 13 | waipawa
# Processing Record 4 of Set 13 | hailar
# Processing Record 5 of Set 13 | kavaratti
# Processing Record 6 of Set 13 | yuzhne
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | voyvozh
# Processing Record 9 of Set 13 | zeya
# Processing Record 10 of Set 13 | ust-kuyga
# Processing Record 11 of Set 13 | maniitsoq
# Processing Record 12 of Set 13 | irbeyskoye
# Processing Record 13 of Set 13 | saint-denis
# Processing Record 14 of Set 13 | nagato
# Processing Record 15 of Set 13 | san rafael del sur
# Processing Record 16 of Set 13 | manjacaze
# Processing Record 17 of Set 13 | sorong
# Processing Record 18 of Set 13 | aginskoye
# Processing Record 19 of Set 13 | vila
# Processing Record 20 of Set 13 | jackson
# Processing Record 21 of Set 13 | avera
# Processing Record 22 of Set 13 | cabedelo
# Processing Record 23 of Set 13 | kadhan
# Processing Record 24 of Set 13 | corbelia
# Processing Record 25 of Set 13 | lensk
# Processing Record 26 of Set 13 | strezhevoy
# Processing Record 27 of Set 13 | dudinka
# Processing Record 28 of Set 13 | bujumbura
# Processing Record 29 of Set 13 | san angelo
# Processing Record 30 of Set 13 | yulara
# Processing Record 31 of Set 13 | ntcheu
# Processing Record 32 of Set 13 | rio gallegos
# Processing Record 33 of Set 13 | kavaje
# Processing Record 34 of Set 13 | ust-nera
# Processing Record 35 of Set 13 | road town
# Processing Record 36 of Set 13 | iskateley
# Processing Record 37 of Set 13 | galich
# Processing Record 38 of Set 13 | pecos
# Processing Record 39 of Set 13 | pathein
# Processing Record 40 of Set 13 | wynyard
# Processing Record 41 of Set 13 | fuerte
# Processing Record 42 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 13 | shahrud
# Processing Record 44 of Set 13 | nanpiao
# Processing Record 45 of Set 13 | severo-yeniseyskiy
# Processing Record 46 of Set 13 | mackenzie
# Processing Record 47 of Set 13 | finschhafen
# Processing Record 48 of Set 13 | ojinaga
# Processing Record 49 of Set 13 | neyveli
# Processing Record 50 of Set 13 | cururupu
# Processing Record 1 of Set 14 | birjand
# Processing Record 2 of Set 14 | tahara
# Processing Record 3 of Set 14 | kampot
# Processing Record 4 of Set 14 | burica
# City not found. Skipping...
# Processing Record 5 of Set 14 | kiruna
# Processing Record 6 of Set 14 | micheweni
# Processing Record 7 of Set 14 | grootfontein
# Processing Record 8 of Set 14 | abha
# Processing Record 9 of Set 14 | sorland
# Processing Record 10 of Set 14 | puerto escondido
# Processing Record 11 of Set 14 | tazovskiy
# Processing Record 12 of Set 14 | zhezkazgan
# Processing Record 13 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 14 | bani
# Processing Record 15 of Set 14 | linfen
# Processing Record 16 of Set 14 | yalvac
# Processing Record 17 of Set 14 | sao gabriel da cachoeira
# Processing Record 18 of Set 14 | breytovo
# Processing Record 19 of Set 14 | katete
# Processing Record 20 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 14 | chulumani
# Processing Record 22 of Set 14 | husavik
# Processing Record 23 of Set 14 | puerto palomas
# Processing Record 24 of Set 14 | afua
# Processing Record 25 of Set 14 | santo antonio do leverger
# Processing Record 26 of Set 14 | gibsons
# Processing Record 27 of Set 14 | tapes
# Processing Record 28 of Set 14 | halifax
# Processing Record 29 of Set 14 | naco
# Processing Record 30 of Set 14 | lingao
# Processing Record 31 of Set 14 | hirara
# Processing Record 32 of Set 14 | sabang
# Processing Record 33 of Set 14 | niksar
# Processing Record 34 of Set 14 | joshimath
# Processing Record 35 of Set 14 | kumluca
# Processing Record 36 of Set 14 | khandyga
# Processing Record 37 of Set 14 | urgut
# Processing Record 38 of Set 14 | altay
# Processing Record 39 of Set 14 | morondava
# Processing Record 40 of Set 14 | atar
# Processing Record 41 of Set 14 | hay river
# Processing Record 42 of Set 14 | lleida
# Processing Record 43 of Set 14 | sioux lookout
# Processing Record 44 of Set 14 | guarapari
# Processing Record 45 of Set 14 | kayes
# Processing Record 46 of Set 14 | barranca
# Processing Record 47 of Set 14 | orlik
# Processing Record 48 of Set 14 | singaraja
# Processing Record 49 of Set 14 | east lansing
# Processing Record 50 of Set 14 | port macquarie
# Processing Record 1 of Set 15 | gheraesti
# Processing Record 2 of Set 15 | bezhetsk
# Processing Record 3 of Set 15 | aswan
# Processing Record 4 of Set 15 | fiumicino
# Processing Record 5 of Set 15 | brufut
# Processing Record 6 of Set 15 | vilhena
# Processing Record 7 of Set 15 | lodja
# Processing Record 8 of Set 15 | deputatskiy
# Processing Record 9 of Set 15 | ulaanbaatar
# Processing Record 10 of Set 15 | vila do maio
# Processing Record 11 of Set 15 | logan lake
# Processing Record 12 of Set 15 | iranshahr
# Processing Record 13 of Set 15 | oda
# Processing Record 14 of Set 15 | dicabisagan
# Processing Record 15 of Set 15 | pedernales
# Processing Record 16 of Set 15 | umiray
# Processing Record 17 of Set 15 | naberera
# Processing Record 18 of Set 15 | bay roberts
# Processing Record 19 of Set 15 | katherine
# Processing Record 20 of Set 15 | callaway
# Processing Record 21 of Set 15 | labuhan
# Processing Record 22 of Set 15 | socorro
# Processing Record 23 of Set 15 | ketchikan
# Processing Record 24 of Set 15 | ossora
# Processing Record 25 of Set 15 | borogontsy
# Processing Record 26 of Set 15 | lopukhiv
# Processing Record 27 of Set 15 | nemuro
# Processing Record 28 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 15 | eyl
# Processing Record 30 of Set 15 | malartic
# Processing Record 31 of Set 15 | sant julia de loria
# Processing Record 32 of Set 15 | minggang
# Processing Record 33 of Set 15 | aksu
# Processing Record 34 of Set 15 | ondangwa
# Processing Record 35 of Set 15 | westpunt
# City not found. Skipping...
# Processing Record 36 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 15 | vasterhaninge
# Processing Record 38 of Set 15 | arlit
# Processing Record 39 of Set 15 | opuwo
# Processing Record 40 of Set 15 | kindu
# Processing Record 41 of Set 15 | pochutla
# Processing Record 42 of Set 15 | netrakona
# Processing Record 43 of Set 15 | hami
# Processing Record 44 of Set 15 | anloga
# Processing Record 45 of Set 15 | portsmouth
# Processing Record 46 of Set 15 | seybaplaya
# Processing Record 47 of Set 15 | carbonear
# Processing Record 48 of Set 15 | ouargaye
# Processing Record 49 of Set 15 | key west
# Processing Record 50 of Set 15 | asmara
# Processing Record 1 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 16 | bucak
# Processing Record 3 of Set 16 | guiratinga
# Processing Record 4 of Set 16 | kulhudhuffushi
# Processing Record 5 of Set 16 | chapleau
# Processing Record 6 of Set 16 | havelock
# Processing Record 7 of Set 16 | yatou
# Processing Record 8 of Set 16 | miamisburg
# Processing Record 9 of Set 16 | rio grande
# Processing Record 10 of Set 16 | sao jose de piranhas
# Processing Record 11 of Set 16 | pitkyaranta
# Processing Record 12 of Set 16 | havre-saint-pierre
# Processing Record 13 of Set 16 | loandjili
# Processing Record 14 of Set 16 | kurumkan
# Processing Record 15 of Set 16 | ingham
# Processing Record 16 of Set 16 | hovd
# Processing Record 17 of Set 16 | jalu
# Processing Record 18 of Set 16 | hambantota
# Processing Record 19 of Set 16 | bambanglipuro
# Processing Record 20 of Set 16 | mercedes
# Processing Record 21 of Set 16 | adamovka
# Processing Record 22 of Set 16 | henderson
# Processing Record 23 of Set 16 | muroto
# Processing Record 24 of Set 16 | muli
# Processing Record 25 of Set 16 | lidorikion
# City not found. Skipping...
# Processing Record 26 of Set 16 | uruguaiana
# Processing Record 27 of Set 16 | komsomolskiy
# Processing Record 28 of Set 16 | buchanan
# Processing Record 29 of Set 16 | catalao
# Processing Record 30 of Set 16 | dunbar
# Processing Record 31 of Set 16 | rawson
# Processing Record 32 of Set 16 | truro
# Processing Record 33 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 16 | mayskiy
# Processing Record 35 of Set 16 | carbonia
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
# Add data to DataFrame
city_df = pd.DataFrame(city_data)

# Re-order the data
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_df = city_df[new_column_order]

# Drop the date column
city_df = city_df.drop(columns="Date")
city_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Okaihau      NZ -35.3167  173.7833     61.52        92
# 1  Praia Da Vitoria      PT  38.7333  -27.0667     60.76        94
# 2      Punta Arenas      CL -53.1500  -70.9167     41.11        80
# 3              Asau      RO  46.4333   26.4000     44.96        95
# 4          Eldorado      BR -23.7869  -54.2836     69.40        87
# 5           Ushuaia      AR -54.8000  -68.3000     38.86        70
# 6        The Valley      AI  18.2170  -63.0578     78.66        94
# 7           Alzamay      RU  55.5562   98.6644     56.52        58
# 8         Busselton      AU -33.6500  115.3333     57.36        81
# 9        Chokurdakh      RU  70.6333  147.9167     20.41        90
#
#    Cloudiness  Wind Speed Current Description
# 0          81        4.90       broken clouds
# 1          20        1.63          few clouds
# 2          89        7.31     overcast clouds
# 3          71        2.73       broken clouds
# 4          16        6.53          few clouds
# 5          20        4.61          few clouds
# 6          20        5.75          few clouds
# 7          82        5.82       broken clouds
# 8           0        4.79           clear sky
# 9          54        9.10       broken clouds

# %%
# Export to csv
output_data_file = "WeatherPy_Database.csv"

city_df.to_csv(output_data_file, index_label="City_ID")
